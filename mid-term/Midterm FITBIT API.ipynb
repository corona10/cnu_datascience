# %%
# gather_keys_oauth2.py로 키 값 가져 올것
import fitbit
import json
clientID = '227L4P'
clientSecret = 'bdd25aad162c4bd752d3d5ab330bc210'
accessToken = 'eyJhbGciOiJIUzI1NiJ9.eyJleHAiOjE0NjE0MjE0MTUsInNjb3BlcyI6InJ3ZWkgcnBybyByaHIgcmxvYyBybnV0IHJzbGUgcnNldCByc29jIHJhY3QiLCJzdWIiOiI0RkcyNUIiLCJhdWQiOiIyMjdMNFAiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJpYXQiOjE0NjE0MTc4MTV9.zjdvEfdfRgF2P_q7pdIxlqtGtCxNy8vRoh2u7l_kZIA'
refreshToken = '259ce4e4f8e394d51213e959976b108514d11995829818ea97b6c04a8150650b'

# %%
authd_client = fitbit.Fitbit('227L4P', 'bdd25aad162c4bd752d3d5ab330bc210',
                            access_token = accessToken, refresh_token = refreshToken)

# %%
authd_client.sleep(date = '2016-04-22')
# Out:
# {u'sleep': [{u'awakeCount': 2,
#    u'awakeDuration': 2,
#    u'awakeningsCount': 14,
#    u'dateOfSleep': u'2016-04-22',
#    u'duration': 12600000,
#    u'efficiency': 90,
#    u'isMainSleep': True,
#    u'logId': 11456037683,
#    u'minuteData': [{u'dateTime': u'01:30:00', u'value': u'2'},
#     {u'dateTime': u'01:31:00', u'value': u'2'},
#     {u'dateTime': u'01:32:00', u'value': u'3'},
#     {u'dateTime': u'01:33:00', u'value': u'2'},
#     {u'dateTime': u'01:34:00', u'value': u'1'},
#     {u'dateTime': u'01:35:00', u'value': u'1'},
#     {u'dateTime': u'01:36:00', u'value': u'1'},
#     {u'dateTime': u'01:37:00', u'value': u'1'},
#     {u'dateTime': u'01:38:00', u'value': u'1'},
#     {u'dateTime': u'01:39:00', u'value': u'1'},
#     {u'dateTime': u'01:40:00', u'value': u'1'},
#     {u'dateTime': u'01:41:00', u'value': u'1'},
#     {u'dateTime': u'01:42:00', u'value': u'1'},
#     {u'dateTime': u'01:43:00', u'value': u'1'},
#     {u'dateTime': u'01:44:00', u'value': u'1'},
# ...

# %%
intradayS = authd_client.intraday_time_series('activities/steps', base_date = '2016-04-23', detail_level = '1min', start_time= None, end_time= None)
f = open('datadumpSteps.json', 'w')
json.dump(intradayS, f)

# %%
intradayH = authd_client.intraday_time_series('activities/heart', base_date = '2016-04-23', detail_level = '1min', start_time= None, end_time= None)
f = open('datadumpHearts.json', 'w')
json.dump(intradayH, f)

# %%
intradaySleep = authd_client.intraday_time_series('activities/heart', base_date = '2016-04-23', detail_level = '1min', start_time= None, end_time= None)
f = open('datadumpHearts.json', 'w')
json.dump(intradayH, f)
